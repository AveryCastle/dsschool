# %%
import pandas as pd

# %%
train = pd.read_csv("./datas/train.csv", parse_dates=["datetime"])

print(train.shape)
train.head()
# Out:
# (10886, 12)
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
train["datetime-year"] = train["datetime"].dt.year
train["datetime-month"] = train["datetime"].dt.month
train["datetime-day"] = train["datetime"].dt.day
train["datetime-hour"] = train["datetime"].dt.hour
train["datetime-minute"] = train["datetime"].dt.minute
train["datetime-second"] = train["datetime"].dt.second

print(train.shape)
train[["datetime", "datetime-year", "datetime-month", "datetime-day", "datetime-hour", "datetime-minute", "datetime-second"]].head()
# Out:
# (10886, 18)
#              datetime  datetime-year  datetime-month  datetime-day  \
# 0 2011-01-01 00:00:00           2011               1             1
# 1 2011-01-01 01:00:00           2011               1             1
# 2 2011-01-01 02:00:00           2011               1             1
# 3 2011-01-01 03:00:00           2011               1             1
# 4 2011-01-01 04:00:00           2011               1             1
#
#    datetime-hour  datetime-minute  datetime-second
# 0              0                0                0
# 1              1                0                0
# 2              2                0                0
# 3              3                0                0
# 4              4                0                0

# %%
train["datetime-dayofweek"] = train["datetime"].dt.dayofweek

print(train.shape)
train[["datetime", "datetime-dayofweek"]].head()
# Out:
# (10886, 19)
#              datetime  datetime-dayofweek
# 0 2011-01-01 00:00:00                   5
# 1 2011-01-01 01:00:00                   5
# 2 2011-01-01 02:00:00                   5
# 3 2011-01-01 03:00:00                   5
# 4 2011-01-01 04:00:00                   5

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# %%
figure, ax1 = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18, 4)

sns.pointplot(data=train, x="datetime-hour", y="count", ax=ax1)

figure, ax2 = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18, 4)

sns.pointplot(data=train, x="datetime-hour", y="count", hue="workingday", ax=ax2)

figure, ax3 = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18, 4)

sns.pointplot(data=train, x="datetime-hour", y="count", hue="datetime-dayofweek", ax=ax3)

# %%
train.loc[(train["datetime-hour"] >= 6) & (train["datetime-hour"] <=9), "office-going-hour"] = 1
train["office-going-hour"] = (train["office-going-hour"] == 1)

train.loc[(train["datetime-hour"] >= 16) & (train["datetime-hour"] <=20), "office-closing-hour"] = 1
train["office-closing-hour"] = (train["office-closing-hour"] == 1)

# print(train.shape)
# train.head()
# Out:
# Empty DataFrame
# Columns: [datetime, season, holiday, workingday, weather, temp, atemp, humidity, windspeed, casual, registered, count, datetime-year, datetime-month, datetime-day, datetime-hour, datetime-minute, datetime-second, datetime-dayofweek, office-going-hour, office-closing-hour]
# Index: []
#
# [0 rows x 21 columns]

# %%
figure, ax1 = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18, 4)

sns.pointplot(data=train, x="humidity", y="count", ax=ax1)

# %% [markdown]
# ## 0.39 이하 score 얻는 방법

# %%
#log 씌워서 데이터 얻은 걸, kaggle에 올릴 땐 log를 뺀 걸로 올린다.
# np.exp(predictions) - 1
# 평가방법에 대해서 잘 알고
